# %%
import pandas as pd

file_path = r"C:\Users\Aakriti K C\Desktop\DA and AI\project 1 IMDB\bda66-imdb-movie-reviews-scraping-cleaning-the-movie-ratings-bda66imdb-s526124\most_popular_movies.csv"
df = pd.read_csv(file_path)

# %%
# Info about the dataset
print("Dataset Info Before Cleaning:")
print(df.info())
print("\nSample Data:")
print(df.head())
# Out:
# Dataset Info Before Cleaning:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         300 non-null    object
#  1   URL           300 non-null    object
#  2   Description   300 non-null    object
#  3   Best Rating   270 non-null    float64
#  4   Worst Rating  270 non-null    float64
#  5   Rating Value  270 non-null    float64
#  6   Genre         300 non-null    object
#  7   Duration      282 non-null    object
# dtypes: float64(3), object(5)
# memory usage: 18.9+ KB
# None
#
# Sample Data:
#             Title                                     URL  \
# 0  Wicked: Part I   https://www.imdb.com/title/tt1262426/
# 1    Gladiator II   https://www.imdb.com/title/tt9218128/
# 2         Moana 2  https://www.imdb.com/title/tt13622970/
# 3       Gladiator   https://www.imdb.com/title/tt0172495/
# ...

# %%
# Handling missing values
# Replacing "N/A" and empty strings with NaN
df.replace("N/A", pd.NA)

# Filling missing values in specific columns
df['Description'] = df['Description'].fillna("No description available")
df['Genre'] = df['Genre'].fillna("Unknown")

# Dropping rows where critical columns are missing
df.dropna(subset=['Title', 'Best Rating', 'Worst Rating','Rating Value'])

# Removing duplicates
df.drop_duplicates(subset = ['Title'])
# Out:
#                                     Title  \
# 0                          Wicked: Part I
# 1                            Gladiator II
# 2                                 Moana 2
# 3                               Gladiator
# 4                           The Substance
# ..                                    ...
# 95  The Ministry of Ungentlemanly Warfare
# 96                           The Fall Guy
# 97                                  Alien
# 98                               Juror #2
# 99                Small Things Like These
#
#                                        URL  \
# 0    https://www.imdb.com/title/tt1262426/
# 1    https://www.imdb.com/title/tt9218128/
# 2   https://www.imdb.com/title/tt13622970/
# 3    https://www.imdb.com/title/tt0172495/
# 4   https://www.imdb.com/title/tt17526714/
# ..                                     ...
# 95   https://www.imdb.com/title/tt5177120/
# 96   https://www.imdb.com/title/tt1684562/
# 97   https://www.imdb.com/title/tt0078748/
# ...

# %%
# Info after cleaning
print("\nDataset Info After Cleaning:")
print(df.info())

# Saving the cleaned data
cleaned_file_path = r"C:\Users\Aakriti K C\Desktop\DA and AI\project 1 IMDB\bda66-imdb-movie-reviews-scraping-cleaning-the-movie-ratings-bda66imdb-s526124\cleaned_most_popular_movies2.csv"
df.to_csv(cleaned_file_path, index=False)
print(f"Cleaned data saved to {cleaned_file_path}")
# Out:
# Dataset Info After Cleaning:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         300 non-null    object
#  1   URL           300 non-null    object
#  2   Description   300 non-null    object
#  3   Best Rating   270 non-null    float64
#  4   Worst Rating  270 non-null    float64
#  5   Rating Value  270 non-null    float64
#  6   Genre         300 non-null    object
#  7   Duration      282 non-null    object
# dtypes: float64(3), object(5)
# memory usage: 18.9+ KB
# None
# Cleaned data saved to C:\Users\Aakriti K C\Desktop\DA and AI\project 1 IMDB\bda66-imdb-movie-reviews-scraping-cleaning-the-movie-ratings-bda66imdb-s526124\cleaned_most_popular_movies2.csv
